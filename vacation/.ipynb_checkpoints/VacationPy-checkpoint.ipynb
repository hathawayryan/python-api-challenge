# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df = pd.read_csv("../weather/weather.csv")

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = weather_df[["Latitude", "Longitude"]].astype(float)

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
#weather_data = weather_df.dropna()
humidity = weather_data["Humidity"].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f06db67b4b47> in <module>
#       2 fig = gmaps.figure()
#       3
# ----> 4 heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
#       5                                  dissipating=False, max_intensity=100,
#       6                                  point_radius = 2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     262         A :class:`gmaps.Heatmap` or a :class:`gmaps.WeightedHeatmap` widget.
#     263     """
# --> 264     widget_args, is_weighted = _heatmap_options(
#     265         locations, weights, max_intensity, dissipating, point_radius,
#     266         opacity, gradient
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in _heatmap_options(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     206     else:
#     207         if len(weights) != len(locations):
# --> 208             raise ValueError(
#     209                 'weights must be of the same length as locations or None')
#     210         is_weighted = True
#
# ValueError: weights must be of the same length as locations or None

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_good_conditions = weather_data[weather_data['Humidity'] < 50]

weather_good_conditions = weather_good_conditions[weather_good_conditions['Wind Speed'] < 10]

weather_good_conditions = weather_good_conditions[weather_good_conditions['Temperature'] > 55]
weather_good_conditions = weather_good_conditions[weather_good_conditions['Temperature'] < 80]


weather_good_conditions
# Out:
#                City  City ID Country  Latitude  Longitude  Temperature  \
# 20           hobart  2163355      AU    -42.88     147.33        65.32
# 45      san quintin  3984997      MX     30.48    -115.95        64.76
# 60      new norfolk  2155415      AU    -42.78     147.06        66.51
# 164       jaisalmer  1269507      IN     26.91      70.92        57.02
# 220           bondo   218253      CD      3.81      23.69        66.60
# 237       rivadavia  3838759      AR    -33.19     -68.46        78.80
# 271          parana  3841956      AR    -31.73     -60.52        72.00
# 276           gusau  2339937      NG     12.16       6.66        71.10
# 279    san patricio  4726521      US     28.02     -97.52        65.34
# 287         malakal   370737      SS      9.53      31.66        75.27
# 364       springbok  3361142      ZA    -29.66      17.89        75.87
# 368         salinas  5391295      US     36.68    -121.66        63.01
# 402       machalpur  1264653      IN     24.13      76.30        55.63
# 429         buckeye  5287262      US     33.37    -112.58        65.01
# 431        rosarito  3988392      MX     32.33    -117.03        76.06
# 437            tezu  1254709      IN     27.92      96.17        57.02
# 460       porbandar  1259395      IN     21.64      69.61        65.97
# 478  puerto penasco  3991347      MX     31.32    -113.53        73.99
# 496            buin  3897774      CL    -33.73     -70.75        76.69
# 523         ondjiva  3346821      AO    -17.07      15.73        74.64
# 538          austin  4671654      US     30.27     -97.74        59.27
#
#      Humidity  Cloudiness  Wind Speed
# 20         48          40        5.82
# 45         38          28        9.64
# 60         42          14        1.99
# 164        32         100        5.41
# 220        45          35        0.38
# 237        26           0        4.70
# 271        42           0        5.10
# 276        23           0        8.84
# 279        40          20        2.93
# 287        33           6        6.51
# 364        31          98        2.42
# 368        30           1        4.03
# 402        39          74        1.25
# 429        22           0        0.98
# 431        12           1        4.70
# 437        37           0        3.56
# 460        35           0        8.75
# 478        17           0        7.00
# 496        26           0        9.17
# 523        44          95        9.53
# 538        36           1        4.21

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = weather_good_conditions


base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in hotel_df.iterrows():

    params = {
    "location": f'{row.Latitude},{row.Longitude}', 
    'radius': '5000',
    #'circle':f'5000@{row.Latitude},{row.Longitude}',
    #"rankby": "distance",
    "type": "lodging",
    "key": g_key,
    'keyword' : 'hotel'
}
    
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}")
    response = requests.get(base_url, params=params).json()
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        hotel_df.loc[index, 'address'] = results[0]['vicinity']
        
            
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 20
# Closest hotel is MACq 01 Hotel.
# ------------
# Retrieving Results for Index 45
# Closest hotel is Old Mill Hotel.
# ------------
# Retrieving Results for Index 60
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 164
# Closest hotel is Jaisalmer Marriott Resort & Spa.
# ------------
# Retrieving Results for Index 220
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 237
# Closest hotel is Hotel Pasambay.
# ------------
# Retrieving Results for Index 271
# Closest hotel is Maran Suites & Towers.
# ------------
# Retrieving Results for Index 276
# Closest hotel is Green Scenery Hotel.
# ------------
# Retrieving Results for Index 279
# Closest hotel is Americas Best Value Inn Sinton.
# ------------
# Retrieving Results for Index 287
# Closest hotel is Nile Palace Hotel.
# ------------
# Retrieving Results for Index 364
# Closest hotel is Springbok Inn by Country Hotels.
# ------------
# Retrieving Results for Index 368
# Closest hotel is Best Western Salinas Monterey Hotel.
# ------------
# Retrieving Results for Index 402
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 429
# Closest hotel is Buckeye Motor Hotel.
# ------------
# Retrieving Results for Index 431
# Closest hotel is Castillos del Mar.
# ------------
# Retrieving Results for Index 437
# Closest hotel is Oshin Hotel.
# ------------
# Retrieving Results for Index 460
# Closest hotel is Lords Inn Porbandar.
# ------------
# Retrieving Results for Index 478
# Closest hotel is Peñasco Del Sol Hotel and Conference Center.
# ------------
# Retrieving Results for Index 496
# Closest hotel is Motel INSIDE.
# ------------
# Retrieving Results for Index 523
# Closest hotel is Villa Okapale.
# ------------
# Retrieving Results for Index 538
# Closest hotel is Hotel Indigo Austin Downtown - University.
# ------------

# %%
hotel_df
# Out:
#                City  City ID Country  Latitude  Longitude  Temperature  \
# 20           hobart  2163355      AU    -42.88     147.33        65.32
# 45      san quintin  3984997      MX     30.48    -115.95        64.76
# 60      new norfolk  2155415      AU    -42.78     147.06        66.51
# 164       jaisalmer  1269507      IN     26.91      70.92        57.02
# 220           bondo   218253      CD      3.81      23.69        66.60
# 237       rivadavia  3838759      AR    -33.19     -68.46        78.80
# 271          parana  3841956      AR    -31.73     -60.52        72.00
# 276           gusau  2339937      NG     12.16       6.66        71.10
# 279    san patricio  4726521      US     28.02     -97.52        65.34
# 287         malakal   370737      SS      9.53      31.66        75.27
# 364       springbok  3361142      ZA    -29.66      17.89        75.87
# 368         salinas  5391295      US     36.68    -121.66        63.01
# 402       machalpur  1264653      IN     24.13      76.30        55.63
# 429         buckeye  5287262      US     33.37    -112.58        65.01
# 431        rosarito  3988392      MX     32.33    -117.03        76.06
# 437            tezu  1254709      IN     27.92      96.17        57.02
# 460       porbandar  1259395      IN     21.64      69.61        65.97
# 478  puerto penasco  3991347      MX     31.32    -113.53        73.99
# 496            buin  3897774      CL    -33.73     -70.75        76.69
# 523         ondjiva  3346821      AO    -17.07      15.73        74.64
# 538          austin  4671654      US     30.27     -97.74        59.27
#
#      Humidity  Cloudiness  Wind Speed  \
# 20         48          40        5.82
# 45         38          28        9.64
# 60         42          14        1.99
# 164        32         100        5.41
# 220        45          35        0.38
# 237        26           0        4.70
# 271        42           0        5.10
# 276        23           0        8.84
# 279        40          20        2.93
# 287        33           6        6.51
# 364        31          98        2.42
# 368        30           1        4.03
# 402        39          74        1.25
# 429        22           0        0.98
# 431        12           1        4.70
# 437        37           0        3.56
# 460        35           0        8.75
# 478        17           0        7.00
# 496        26           0        9.17
# 523        44          95        9.53
# 538        36           1        4.21
#
#                                       Hotel Name  \
# 20                                 MACq 01 Hotel
# 45                                Old Mill Hotel
# 60                                           NaN
# 164              Jaisalmer Marriott Resort & Spa
# 220                                          NaN
# 237                               Hotel Pasambay
# 271                        Maran Suites & Towers
# 276                          Green Scenery Hotel
# 279               Americas Best Value Inn Sinton
# 287                            Nile Palace Hotel
# 364              Springbok Inn by Country Hotels
# 368          Best Western Salinas Monterey Hotel
# 402                                          NaN
# 429                          Buckeye Motor Hotel
# 431                            Castillos del Mar
# 437                                  Oshin Hotel
# 460                          Lords Inn Porbandar
# 478  Peñasco Del Sol Hotel and Conference Center
# 496                                 Motel INSIDE
# 523                                Villa Okapale
# 538    Hotel Indigo Austin Downtown - University
#
#                                                address
# 20                                18 Hunter St, Hobart
# 45                                            Ensenada
# 60                                                 NaN
# 164  Jaisalmer - Sam - Dhanana Rd, Police Line, Jai...
# 220                                                NaN
# 237                            Sarmiento 14, Rivadavia
# 271           Av, Alameda de la Federación 698, Paraná
# 276                                              Gusau
# 279                                 8108 US-77, Sinton
# 287                                            Malakal
# 364                          Voortrekker St, Springbok
# 368                               175 Kern St, Salinas
# 402                                                NaN
# 429                              202 E, MC 85, Buckeye
# 431  Carretera Tijuana-Ensenada Km. 29.5, Castillos...
# 437  Main Bazaar Road, Oshin Market, Lohit District...
# 460  Chaupati Cricket Ground, near Circuit House, G...
# 478  Paseo las Glorias #1, Bella Vista, Centro, Pue...
# 496       Panamericana Sur carretera 5 sur km 33, Buin
# 523                                            Ondjiva
# 538                           810 Red River St, Austin

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=info_box_template
)

# Display figure
fig.add_layer(hotel_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
